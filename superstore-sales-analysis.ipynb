# %% [markdown]
# ## This is the second work from "Data Analysis with Python Course with Nevin Yılmaz". In this work I analysed the sales of superstore that  mostly sells office supplies in USA.

# %% [markdown]
# # Quick look to the data <a id="introduction"></a>
# This dataset is  from the course that I mentioned in above. The purpose of the dataset is to have insight of superstore'sales. In this dataset our target variable is "Sales".
# # Data Exploration <a id="subparagraph1"></a>
# The columns that are given in dataset some of them are self-explanatory so I did not write explanation.😉😎
#
# ***Row ID:***
#
# ***Order ID:***
#
# ***Order Date:***
#
# ***Ship Date:***
#
# ***Ship Mode:*** Different ship mode, First Class, Same day, Standard Class, Third Class.
#
# ***Customer ID:***
#
# ***Customer Name:***
#
# ***Segment:*** Different segments for company, Consumer, Corporate, Home Office.
#
# ***Country:*** USA
#
# ***City:*** Different cities in the USA, New york, Los Angeles, Philadelphia etc.
#
# ***State:*** Different states in the USA, Kentucky, California, Folrida etc.
#
# ***Postal Code:***
#
# ***Region:*** Different region in the USA, West, South, Central, East.
#
# ***Product ID:***
#
# ***Category:*** Mostly Office supplies then furniture and technology.
#
# ***Sub-Category:***
#
# ***Product Name:***
#
#
# ***Target variable:*** Sales

# %% [markdown]
# # Questions to be answered <a id="paragraph1"></a>
#
# * What day of the week are our sales high on average?
#
# * What is monthly average sales?
#
# * What are the year over growth year/ total sales over the years?
#
# * Who are the top customer of all times?
#
# * What are the highest sales by category?
#
# * Which city does have the highest sales?

# %%
from datetime import timedelta
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/sales-forecasting/train.csv

# %%
data = pd.read_csv("/kaggle/input/sales-forecasting/train.csv")
data.head()
#It is a method that I can use to look data's first rows quickly.
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 1       2  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2       3  CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 3       4  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 4       5  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region       Product ID         Category Sub-Category  \
# 0      42420.0  South  FUR-BO-10001798        Furniture    Bookcases
# 1      42420.0  South  FUR-CH-10000454        Furniture       Chairs
# 2      90036.0   West  OFF-LA-10000240  Office Supplies       Labels
# 3      33311.0  South  FUR-TA-10000577        Furniture       Tables
# 4      33311.0  South  OFF-ST-10000760  Office Supplies      Storage
#
#                                         Product Name     Sales
# 0                  Bush Somerset Collection Bookcase  261.9600
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775
# 4                     Eldon Fold 'N Roll Cart System   22.3680

# %%
data.info()
#It is a method that I can use to get general information about dataset(column's name, feature's type) and check if there is any missing information in our dataset.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9800 non-null   int64
#  1   Order ID       9800 non-null   object
#  2   Order Date     9800 non-null   object
#  3   Ship Date      9800 non-null   object
#  4   Ship Mode      9800 non-null   object
#  5   Customer ID    9800 non-null   object
#  6   Customer Name  9800 non-null   object
#  7   Segment        9800 non-null   object
#  8   Country        9800 non-null   object
#  9   City           9800 non-null   object
#  10  State          9800 non-null   object
#  11  Postal Code    9789 non-null   float64
#  12  Region         9800 non-null   object
#  13  Product ID     9800 non-null   object
#  14  Category       9800 non-null   object
#  15  Sub-Category   9800 non-null   object
#  16  Product Name   9800 non-null   object
#  17  Sales          9800 non-null   float64
# dtypes: float64(2), int64(1), object(15)
# memory usage: 1.3+ MB

# %%
data['Order Date'] = pd.to_datetime(data['Order Date'])
data['Ship Date'] = pd.to_datetime(data['Ship Date'])
#Here, I changed the column's type "object" to datetime by using "datetime" module in pandas.

# %%
data.describe().T
#It is the method that I use to obtain statistical informations for numerical columns.
# Out:
#               count          mean           std       min        25%  \
# Row ID       9800.0   4900.500000   2829.160653     1.000   2450.750
# Postal Code  9789.0  55273.322403  32041.223413  1040.000  23223.000
# Sales        9800.0    230.769059    626.651875     0.444     17.248
#
#                   50%        75%       max
# Row ID        4900.50   7350.250   9800.00
# Postal Code  58103.00  90008.000  99301.00
# Sales           54.49    210.605  22638.48

# %%
data.columns
#It is the method that I can use to get the column's name in a list format.
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales'],
#       dtype='object')

# %%
category_columns = []
for sutun in data.columns:
 if data[sutun].dtypes == 'object':
   category_columns.append(sutun)
#I created category_columns list to observe the category columns features.

# %%
data[category_columns].describe()
# Out:
#               Order ID       Ship Mode Customer ID  Customer Name   Segment  \
# count             9800            9800        9800           9800      9800
# unique            4922               4         793            793         3
# top     CA-2018-100111  Standard Class    WB-21850  William Brown  Consumer
# freq                14            5859          35             35      5101
#
#               Country           City       State Region       Product ID  \
# count            9800           9800        9800   9800             9800
# unique              1            529          49      4             1861
# top     United States  New York City  California   West  OFF-PA-10001970
# freq             9800            891        1946   3140               19
#
#                Category Sub-Category     Product Name
# count              9800         9800             9800
# unique                3           17             1849
# top     Office Supplies      Binders  Staple envelope
# freq               5909         1492               47

# %%
data['Order Date'] #A series can have only one column in pandas so I used one bracket.
# Out:
# 0      2017-08-11
# 1      2017-08-11
# 2      2017-12-06
# 3      2016-11-10
# 4      2016-11-10
#           ...
# 9795   2017-05-21
# 9796   2016-12-01
# 9797   2016-12-01
# 9798   2016-12-01
# 9799   2016-12-01
# Name: Order Date, Length: 9800, dtype: datetime64[ns]

# %%
data[['Order Date', 'Ship Date']].describe().T
# Here I want to choose two columns from dataframe so I have to use two bracket.
# Out:
#            count unique        top freq      first       last
# Order Date  9800   1230 2017-05-09   38 2015-01-02 2018-12-30
# Ship Date   9800   1326 2018-09-26   34 2015-01-04 2019-05-01

# %%
for column in category_columns:
  print(column)
  print(data[column].value_counts())
  print('END')
  print("")
  #This method gives us to total information about each column's count
# Out:
# Order ID
# CA-2018-100111    14
# CA-2018-157987    12
# CA-2017-165330    11
# US-2017-108504    11
# CA-2017-105732    10
#                   ..
# US-2016-110261     1
# CA-2016-125710     1
# US-2016-137960     1
# CA-2016-124975     1
# CA-2016-142202     1
# Name: Order ID, Length: 4922, dtype: int64
# END
#
# Ship Mode
# Standard Class    5859
# Second Class      1902
# First Class       1501
# Same Day           538
# Name: Ship Mode, dtype: int64
# END
#
# Customer ID
# WB-21850    35
# MA-17560    34
# PP-18955    34
# JL-15835    33
# CK-12205    32
#             ..
# JR-15700     1
# CJ-11875     1
# SC-20845     1
# RE-19405     1
# AO-10810     1
# Name: Customer ID, Length: 793, dtype: int64
# END
#
# Customer Name
# William Brown          35
# Matt Abelman           34
# Paul Prost             34
# John Lee               33
# Chloris Kastensmidt    32
#                        ..
# Jocasta Rupert          1
# Carl Jackson            1
# Sung Chung              1
# Ricardo Emerson         1
# Anthony O'Donnell       1
# Name: Customer Name, Length: 793, dtype: int64
# END
#
# Segment
# Consumer       5101
# Corporate      2953
# Home Office    1746
# Name: Segment, dtype: int64
# END
#
# Country
# United States    9800
# Name: Country, dtype: int64
# END
#
# City
# New York City    891
# Los Angeles      728
# Philadelphia     532
# San Francisco    500
# Seattle          426
#                 ...
# San Mateo          1
# Cheyenne           1
# Conway             1
# Melbourne          1
# Springdale         1
# Name: City, Length: 529, dtype: int64
# END
#
# State
# California              1946
# New York                1097
# Texas                    973
# Pennsylvania             582
# Washington               504
# Illinois                 483
# Ohio                     454
# Florida                  373
# Michigan                 253
# North Carolina           247
# Virginia                 224
# Arizona                  223
# Tennessee                183
# Colorado                 179
# Georgia                  177
# Kentucky                 137
# Indiana                  135
# Massachusetts            135
# Oregon                   122
# New Jersey               122
# Maryland                 105
# Wisconsin                105
# Delaware                  93
# Minnesota                 89
# Connecticut               82
# Missouri                  66
# Oklahoma                  66
# Alabama                   61
# Arkansas                  60
# Rhode Island              55
# Mississippi               53
# Utah                      53
# South Carolina            42
# Louisiana                 41
# Nevada                    39
# Nebraska                  38
# New Mexico                37
# New Hampshire             27
# Iowa                      26
# Kansas                    24
# Idaho                     21
# Montana                   15
# South Dakota              12
# Vermont                   11
# District of Columbia      10
# Maine                      8
# North Dakota               7
# West Virginia              4
# Wyoming                    1
# Name: State, dtype: int64
# END
#
# Region
# West       3140
# East       2785
# Central    2277
# South      1598
# Name: Region, dtype: int64
# END
#
# Product ID
# OFF-PA-10001970    19
# TEC-AC-10003832    18
# FUR-FU-10004270    16
# TEC-AC-10002049    15
# TEC-AC-10003628    15
#                    ..
# OFF-PA-10000919     1
# TEC-MA-10003353     1
# OFF-LA-10003388     1
# OFF-EN-10004206     1
# TEC-PH-10002645     1
# Name: Product ID, Length: 1861, dtype: int64
# END
#
# Category
# Office Supplies    5909
# Furniture          2078
# Technology         1813
# Name: Category, dtype: int64
# END
#
# Sub-Category
# Binders        1492
# Paper          1338
# Furnishings     931
# Phones          876
# Storage         832
# Art             785
# Accessories     756
# Chairs          607
# Appliances      459
# Labels          357
# Tables          314
# Envelopes       248
# Bookcases       226
# Fasteners       214
# Supplies        184
# Machines        115
# Copiers          66
# Name: Sub-Category, dtype: int64
# END
#
# Product Name
# Staple envelope                                                        47
# Staples                                                                46
# Easy-staple paper                                                      44
# Avery Non-Stick Binders                                                20
# Staples in misc. colors                                                18
#                                                                        ..
# Xiaomi Mi3                                                              1
# Universal Ultra Bright White Copier/Laser Paper, 8 1/2" x 11", Ream     1
# Socket Bluetooth Cordless Hand Scanner (CHS)                            1
# Logitech Illuminated Ultrathin Keyboard with Backlighting               1
# LG G2                                                                   1
# Name: Product Name, Length: 1849, dtype: int64
# END

# %% [markdown]
# # Feature Engineering & Data Cleaning <a id="paragraph2"></a>
#
# In this part of I found some missing value. The values that does not sound logical according to Data Exploration. For me I found some outlier values. I tried to reshape these values. For example filling the correspondig column with median and mean values. I take out some of these values in my dataset. I will explain these steps clearly so don't worry. 😉😎

# %%
data['Shipping_timeframe'] = data['Ship Date'] -data['Order Date']
data.head()
#I want to find the shipping timeframe and check the validity.
#I saw that there are negative values but it is not logical.
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156 2017-08-11 2017-11-11    Second Class    CG-12520
# 1       2  CA-2017-152156 2017-08-11 2017-11-11    Second Class    CG-12520
# 2       3  CA-2017-138688 2017-12-06 2017-06-16    Second Class    DV-13045
# 3       4  US-2016-108966 2016-11-10 2016-10-18  Standard Class    SO-20335
# 4       5  US-2016-108966 2016-11-10 2016-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region       Product ID         Category Sub-Category  \
# 0      42420.0  South  FUR-BO-10001798        Furniture    Bookcases
# 1      42420.0  South  FUR-CH-10000454        Furniture       Chairs
# 2      90036.0   West  OFF-LA-10000240  Office Supplies       Labels
# 3      33311.0  South  FUR-TA-10000577        Furniture       Tables
# 4      33311.0  South  OFF-ST-10000760  Office Supplies      Storage
#
#                                         Product Name     Sales  \
# 0                  Bush Somerset Collection Bookcase  261.9600
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775
# 4                     Eldon Fold 'N Roll Cart System   22.3680
#
#   Shipping_timeframe
# 0            92 days
# 1            92 days
# 2          -173 days
# 3           -23 days
# 4           -23 days

# %%
data['Shipping_timeframe'].dtypes
# It is a method to get the type of columns.

data['Shipping_timeframe'].astype('str').str.split(expand=True)
#It is a method to convert column's type to string.

data[['Shipping_timeframe', '_']] = data['Shipping_timeframe'].astype('str').str.split(expand=True)
#I add new column "_" to get rid of the string format of "days" column.

# %%
data['Shipping_timeframe'].dtypes # Type of object is object.
# Out:
# dtype('O')

# %%
data['Shipping_timeframe'] =data['Shipping_timeframe'].astype(int) 
data['Shipping_timeframe'].dtypes
#I converted to type of column's integer because I want to calculations next steps.
# Out:
# dtype('int64')

# %%
data.drop('_', axis=1, inplace=True) 
#It is a method to delete the column in dataset. inplace=True, is that  applies this  permananet changes on dataset.

# %%
data.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156 2017-08-11 2017-11-11    Second Class    CG-12520
# 1       2  CA-2017-152156 2017-08-11 2017-11-11    Second Class    CG-12520
# 2       3  CA-2017-138688 2017-12-06 2017-06-16    Second Class    DV-13045
# 3       4  US-2016-108966 2016-11-10 2016-10-18  Standard Class    SO-20335
# 4       5  US-2016-108966 2016-11-10 2016-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region       Product ID         Category Sub-Category  \
# 0      42420.0  South  FUR-BO-10001798        Furniture    Bookcases
# 1      42420.0  South  FUR-CH-10000454        Furniture       Chairs
# 2      90036.0   West  OFF-LA-10000240  Office Supplies       Labels
# 3      33311.0  South  FUR-TA-10000577        Furniture       Tables
# 4      33311.0  South  OFF-ST-10000760  Office Supplies      Storage
#
#                                         Product Name     Sales  \
# 0                  Bush Somerset Collection Bookcase  261.9600
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775
# 4                     Eldon Fold 'N Roll Cart System   22.3680
#
#    Shipping_timeframe
# 0                  92
# 1                  92
# 2                -173
# 3                 -23
# 4                 -23

# %%
data[data['Shipping_timeframe'] < 0]
#I said that it is not logical to have negative values in this column but I have what should I do?
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 2          3  CA-2017-138688 2017-12-06 2017-06-16    Second Class
# 3          4  US-2016-108966 2016-11-10 2016-10-18  Standard Class
# 4          5  US-2016-108966 2016-11-10 2016-10-18  Standard Class
# 5          6  CA-2015-115812 2015-09-06 2015-06-14  Standard Class
# 6          7  CA-2015-115812 2015-09-06 2015-06-14  Standard Class
# ...      ...             ...        ...        ...             ...
# 9790    9791  CA-2018-144491 2018-03-27 2018-01-04  Standard Class
# 9796    9797  CA-2016-128608 2016-12-01 2016-01-17  Standard Class
# 9797    9798  CA-2016-128608 2016-12-01 2016-01-17  Standard Class
# 9798    9799  CA-2016-128608 2016-12-01 2016-01-17  Standard Class
# 9799    9800  CA-2016-128608 2016-12-01 2016-01-17  Standard Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 2       DV-13045   Darrin Van Huff  Corporate  United States      Los Angeles
# 3       SO-20335    Sean O'Donnell   Consumer  United States  Fort Lauderdale
# 4       SO-20335    Sean O'Donnell   Consumer  United States  Fort Lauderdale
# 5       BH-11710   Brosina Hoffman   Consumer  United States      Los Angeles
# 6       BH-11710   Brosina Hoffman   Consumer  United States      Los Angeles
# ...          ...               ...        ...            ...              ...
# 9790    CJ-12010   Caroline Jumper   Consumer  United States          Houston
# 9796    CS-12490  Cindy Schnelling  Corporate  United States           Toledo
# 9797    CS-12490  Cindy Schnelling  Corporate  United States           Toledo
# 9798    CS-12490  Cindy Schnelling  Corporate  United States           Toledo
# 9799    CS-12490  Cindy Schnelling  Corporate  United States           Toledo
#
#            State  Postal Code   Region       Product ID         Category  \
# 2     California      90036.0     West  OFF-LA-10000240  Office Supplies
# 3        Florida      33311.0    South  FUR-TA-10000577        Furniture
# 4        Florida      33311.0    South  OFF-ST-10000760  Office Supplies
# 5     California      90032.0     West  FUR-FU-10001487        Furniture
# 6     California      90032.0     West  OFF-AR-10002833  Office Supplies
# ...          ...          ...      ...              ...              ...
# 9790       Texas      77070.0  Central  FUR-CH-10001714        Furniture
# 9796        Ohio      43615.0     East  OFF-AR-10001374  Office Supplies
# 9797        Ohio      43615.0     East  TEC-PH-10004977       Technology
# 9798        Ohio      43615.0     East  TEC-PH-10000912       Technology
# 9799        Ohio      43615.0     East  TEC-AC-10000487       Technology
#
#      Sub-Category                                       Product Name  \
# 2          Labels  Self-Adhesive Address Labels for Typewriters b...
# 3          Tables      Bretford CR4500 Series Slim Rectangular Table
# 4         Storage                     Eldon Fold 'N Roll Cart System
# 5     Furnishings  Eldon Expressions Wood and Plastic Desk Access...
# 6             Art                                         Newell 322
# ...           ...                                                ...
# 9790       Chairs     Global Leather & Oak Executive Chair, Burgundy
# 9796          Art           BIC Brite Liner Highlighters, Chisel Tip
# 9797       Phones                                        GE 30524EE4
# 9798       Phones           Anker 24W Portable Micro USB Car Charger
# 9799  Accessories                SanDisk Cruzer 4 GB USB Flash Drive
#
#          Sales  Shipping_timeframe
# 2      14.6200                -173
# 3     957.5775                 -23
# 4      22.3680                 -23
# 5      48.8600                 -84
# 6       7.2800                 -84
# ...        ...                 ...
# 9790  211.2460                 -82
# 9796   10.3680                -319
# 9797  235.1880                -319
# 9798   26.3760                -319
# 9799   10.3840                -319
#
# [1684 rows x 19 columns]

# %%
data[['Shipping_timeframe']][data['Shipping_timeframe'] >= 0].describe()
#I chose the positive values for this column and looked the statistical information.
# Out:
#        Shipping_timeframe
# count         8116.000000
# mean            41.726836
# std             58.037943
# min              0.000000
# 25%              4.000000
# 50%              5.000000
# 75%             89.000000
# max            214.000000

# %%
data_big = data[data['Shipping_timeframe'] >= 0] 

#I created new dataframe "data_big" by choosing positive values of  'Shipping_timeframe'.
#Because, for next steps I will use "data_big"s mean and median values.

data_big.head()
# Out:
#     Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0        1  CA-2017-152156 2017-08-11 2017-11-11    Second Class    CG-12520
# 1        2  CA-2017-152156 2017-08-11 2017-11-11    Second Class    CG-12520
# 12      13  CA-2018-114412 2018-04-15 2018-04-20  Standard Class    AA-10480
# 13      14  CA-2017-161389 2017-05-12 2017-10-12  Standard Class    IM-15070
# 14      15  US-2016-118983 2016-11-22 2016-11-26  Standard Class    HP-14815
#
#     Customer Name      Segment        Country        City           State  \
# 0     Claire Gute     Consumer  United States   Henderson        Kentucky
# 1     Claire Gute     Consumer  United States   Henderson        Kentucky
# 12   Andrew Allen     Consumer  United States     Concord  North Carolina
# 13   Irene Maddox     Consumer  United States     Seattle      Washington
# 14  Harold Pawlan  Home Office  United States  Fort Worth           Texas
#
#     Postal Code   Region       Product ID         Category Sub-Category  \
# 0       42420.0    South  FUR-BO-10001798        Furniture    Bookcases
# 1       42420.0    South  FUR-CH-10000454        Furniture       Chairs
# 12      28027.0    South  OFF-PA-10002365  Office Supplies        Paper
# 13      98103.0     West  OFF-BI-10003656  Office Supplies      Binders
# 14      76106.0  Central  OFF-AP-10002311  Office Supplies   Appliances
#
#                                          Product Name    Sales  \
# 0                   Bush Somerset Collection Bookcase  261.960
# 1   Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.940
# 12                                         Xerox 1967   15.552
# 13        Fellowes PB200 Plastic Comb Binding Machine  407.976
# 14  Holmes Replacement Filter for HEPA Air Cleaner...   68.810
#
#     Shipping_timeframe
# 0                   92
# 1                   92
# 12                   5
# 13                 153
# 14                   4

# %%
data_big["Ship Mode"].unique() # It is a method to get unique values of given column.
# Out:
# array(['Second Class', 'Standard Class', 'First Class', 'Same Day'],
#       dtype=object)

# %%
data_big.groupby('Ship Mode').agg({'Shipping_timeframe':'mean'})
# Out:
#                 Shipping_timeframe
# Ship Mode
# First Class              26.311756
# Same Day                  0.891791
# Second Class             36.224796
# Standard Class           52.805130

# %%
  data_big.groupby('Ship Mode').agg({'Shipping_timeframe':'median'})
# Out:
#                 Shipping_timeframe
# Ship Mode
# First Class                    3.0
# Same Day                       0.0
# Second Class                   4.0
# Standard Class                 6.0

# %%
#For the next steps;
#If shipping time frame is less than zero, look at the shipping mode of that row then
#Look at the median value of this shipping mode and fill the shipping time frame that is less than zero with this median value.

# %%
ship_mode_dic = {"Standard Class":6,
                 "Second Class":4, 
                 "Same Day":0, 
                 "First Class":3}
ship_mode_dic.items()
# Out:
# dict_items([('Standard Class', 6), ('Second Class', 4), ('Same Day', 0), ('First Class', 3)])

# %%
for key, value in ship_mode_dic.items():
  data['Ship Date'] = np.where((data['Shipping_timeframe'] < 0) & (data['Ship Mode'] == key),
                             data['Order Date'] + timedelta(days=value),
                             data['Ship Date'])

# %%
data.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156 2017-08-11 2017-11-11    Second Class    CG-12520
# 1       2  CA-2017-152156 2017-08-11 2017-11-11    Second Class    CG-12520
# 2       3  CA-2017-138688 2017-12-06 2017-12-10    Second Class    DV-13045
# 3       4  US-2016-108966 2016-11-10 2016-11-16  Standard Class    SO-20335
# 4       5  US-2016-108966 2016-11-10 2016-11-16  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region       Product ID         Category Sub-Category  \
# 0      42420.0  South  FUR-BO-10001798        Furniture    Bookcases
# 1      42420.0  South  FUR-CH-10000454        Furniture       Chairs
# 2      90036.0   West  OFF-LA-10000240  Office Supplies       Labels
# 3      33311.0  South  FUR-TA-10000577        Furniture       Tables
# 4      33311.0  South  OFF-ST-10000760  Office Supplies      Storage
#
#                                         Product Name     Sales  \
# 0                  Bush Somerset Collection Bookcase  261.9600
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775
# 4                     Eldon Fold 'N Roll Cart System   22.3680
#
#    Shipping_timeframe
# 0                  92
# 1                  92
# 2                -173
# 3                 -23
# 4                 -23

# %%
data['Shipping_timeframe'] = data['Ship Date'] - data['Order Date']

# %%
data[['Shipping_timeframe', "not_important"]] =data['Shipping_timeframe'].astype('str').str.split(expand=True)

# %%
data['Shipping_timeframe'] = data['Shipping_timeframe'].astype(int)

# %%
data.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156 2017-08-11 2017-11-11    Second Class    CG-12520
# 1       2  CA-2017-152156 2017-08-11 2017-11-11    Second Class    CG-12520
# 2       3  CA-2017-138688 2017-12-06 2017-12-10    Second Class    DV-13045
# 3       4  US-2016-108966 2016-11-10 2016-11-16  Standard Class    SO-20335
# 4       5  US-2016-108966 2016-11-10 2016-11-16  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region       Product ID         Category Sub-Category  \
# 0      42420.0  South  FUR-BO-10001798        Furniture    Bookcases
# 1      42420.0  South  FUR-CH-10000454        Furniture       Chairs
# 2      90036.0   West  OFF-LA-10000240  Office Supplies       Labels
# 3      33311.0  South  FUR-TA-10000577        Furniture       Tables
# 4      33311.0  South  OFF-ST-10000760  Office Supplies      Storage
#
#                                         Product Name     Sales  \
# 0                  Bush Somerset Collection Bookcase  261.9600
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775
# 4                     Eldon Fold 'N Roll Cart System   22.3680
#
#    Shipping_timeframe not_important
# 0                  92          days
# 1                  92          days
# 2                   4          days
# 3                   6          days
# 4                   6          days

# %%
data[data.Shipping_timeframe < 0] 
#I checked an I no longer have data with shipping time frame less than zero.
# Out:
# Empty DataFrame
# Columns: [Row ID, Order ID, Order Date, Ship Date, Ship Mode, Customer ID, Customer Name, Segment, Country, City, State, Postal Code, Region, Product ID, Category, Sub-Category, Product Name, Sales, Shipping_timeframe, not_important]
# Index: []

# %%
data.drop(['Row ID', 'Country','not_important'], 1, inplace=True )

# %%
data[data['Postal Code'].isnull()] 
#It is a method to check if I have null values.
# Out:
#             Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 2234  CA-2018-104066 2018-05-12 2018-10-12  Standard Class    QJ-19255
# 5274  CA-2016-162887 2016-07-11 2016-09-11    Second Class    SV-20785
# 8798  US-2017-150140 2017-06-04 2017-10-04  Standard Class    VM-21685
# 9146  US-2017-165505 2017-01-23 2017-01-27  Standard Class    CB-12535
# 9147  US-2017-165505 2017-01-23 2017-01-27  Standard Class    CB-12535
# 9148  US-2017-165505 2017-01-23 2017-01-27  Standard Class    CB-12535
# 9386  US-2018-127292 2018-01-19 2018-01-23  Standard Class    RM-19375
# 9387  US-2018-127292 2018-01-19 2018-01-23  Standard Class    RM-19375
# 9388  US-2018-127292 2018-01-19 2018-01-23  Standard Class    RM-19375
# 9389  US-2018-127292 2018-01-19 2018-01-23  Standard Class    RM-19375
# 9741  CA-2016-117086 2016-08-11 2016-12-11  Standard Class    QJ-19255
#
#          Customer Name      Segment        City    State  Postal Code Region  \
# 2234      Quincy Jones    Corporate  Burlington  Vermont          NaN   East
# 5274  Stewart Visinsky     Consumer  Burlington  Vermont          NaN   East
# 8798   Valerie Mitchum  Home Office  Burlington  Vermont          NaN   East
# 9146  Claudia Bergmann    Corporate  Burlington  Vermont          NaN   East
# 9147  Claudia Bergmann    Corporate  Burlington  Vermont          NaN   East
# 9148  Claudia Bergmann    Corporate  Burlington  Vermont          NaN   East
# 9386     Raymond Messe     Consumer  Burlington  Vermont          NaN   East
# 9387     Raymond Messe     Consumer  Burlington  Vermont          NaN   East
# 9388     Raymond Messe     Consumer  Burlington  Vermont          NaN   East
# 9389     Raymond Messe     Consumer  Burlington  Vermont          NaN   East
# 9741      Quincy Jones    Corporate  Burlington  Vermont          NaN   East
#
#            Product ID         Category Sub-Category  \
# 2234  TEC-AC-10001013       Technology  Accessories
# 5274  FUR-CH-10000595        Furniture       Chairs
# 8798  TEC-PH-10002555       Technology       Phones
# 9146  TEC-AC-10002926       Technology  Accessories
# 9147  OFF-AR-10003477  Office Supplies          Art
# 9148  OFF-ST-10001526  Office Supplies      Storage
# 9386  OFF-PA-10000157  Office Supplies        Paper
# 9387  OFF-PA-10001970  Office Supplies        Paper
# 9388  OFF-AP-10000828  Office Supplies   Appliances
# 9389  OFF-EN-10001509  Office Supplies    Envelopes
# 9741  FUR-BO-10004834        Furniture    Bookcases
#
#                                            Product Name    Sales  \
# 2234        Logitech ClearChat Comfort/USB Headset H390   205.03
# 5274                    Safco Contoured Stacking Chairs   715.20
# 8798                Nortel Meridian M5316 Digital phone  1294.75
# 9146              Logitech Wireless Marathon Mouse M705    99.98
# 9147                                  4009 Highlighters     8.04
# 9148              Iceberg Mobile Mega Data/Printer Cart  1564.29
# 9386                                          Xerox 191    79.92
# 9387                                         Xerox 1881    12.28
# 9388                    Avanti 4.4 Cu. Ft. Refrigerator   542.94
# 9389                          Poly String Tie Envelopes     2.04
# 9741  Riverside Palais Royal Lawyers Bookcase, Royal...  4404.90
#
#       Shipping_timeframe
# 2234                 153
# 5274                  62
# 8798                 122
# 9146                   4
# 9147                   4
# 9148                   4
# 9386                   4
# 9387                   4
# 9388                   4
# 9389                   4
# 9741                 122

# %%
data[(data.City == 'Burlington') & (data.State == 'Vermont')]
# Out:
#             Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 2234  CA-2018-104066 2018-05-12 2018-10-12  Standard Class    QJ-19255
# 5274  CA-2016-162887 2016-07-11 2016-09-11    Second Class    SV-20785
# 8798  US-2017-150140 2017-06-04 2017-10-04  Standard Class    VM-21685
# 9146  US-2017-165505 2017-01-23 2017-01-27  Standard Class    CB-12535
# 9147  US-2017-165505 2017-01-23 2017-01-27  Standard Class    CB-12535
# 9148  US-2017-165505 2017-01-23 2017-01-27  Standard Class    CB-12535
# 9386  US-2018-127292 2018-01-19 2018-01-23  Standard Class    RM-19375
# 9387  US-2018-127292 2018-01-19 2018-01-23  Standard Class    RM-19375
# 9388  US-2018-127292 2018-01-19 2018-01-23  Standard Class    RM-19375
# 9389  US-2018-127292 2018-01-19 2018-01-23  Standard Class    RM-19375
# 9741  CA-2016-117086 2016-08-11 2016-12-11  Standard Class    QJ-19255
#
#          Customer Name      Segment        City    State  Postal Code Region  \
# 2234      Quincy Jones    Corporate  Burlington  Vermont          NaN   East
# 5274  Stewart Visinsky     Consumer  Burlington  Vermont          NaN   East
# 8798   Valerie Mitchum  Home Office  Burlington  Vermont          NaN   East
# 9146  Claudia Bergmann    Corporate  Burlington  Vermont          NaN   East
# 9147  Claudia Bergmann    Corporate  Burlington  Vermont          NaN   East
# 9148  Claudia Bergmann    Corporate  Burlington  Vermont          NaN   East
# 9386     Raymond Messe     Consumer  Burlington  Vermont          NaN   East
# 9387     Raymond Messe     Consumer  Burlington  Vermont          NaN   East
# 9388     Raymond Messe     Consumer  Burlington  Vermont          NaN   East
# 9389     Raymond Messe     Consumer  Burlington  Vermont          NaN   East
# 9741      Quincy Jones    Corporate  Burlington  Vermont          NaN   East
#
#            Product ID         Category Sub-Category  \
# 2234  TEC-AC-10001013       Technology  Accessories
# 5274  FUR-CH-10000595        Furniture       Chairs
# 8798  TEC-PH-10002555       Technology       Phones
# 9146  TEC-AC-10002926       Technology  Accessories
# 9147  OFF-AR-10003477  Office Supplies          Art
# 9148  OFF-ST-10001526  Office Supplies      Storage
# 9386  OFF-PA-10000157  Office Supplies        Paper
# 9387  OFF-PA-10001970  Office Supplies        Paper
# 9388  OFF-AP-10000828  Office Supplies   Appliances
# 9389  OFF-EN-10001509  Office Supplies    Envelopes
# 9741  FUR-BO-10004834        Furniture    Bookcases
#
#                                            Product Name    Sales  \
# 2234        Logitech ClearChat Comfort/USB Headset H390   205.03
# 5274                    Safco Contoured Stacking Chairs   715.20
# 8798                Nortel Meridian M5316 Digital phone  1294.75
# 9146              Logitech Wireless Marathon Mouse M705    99.98
# 9147                                  4009 Highlighters     8.04
# 9148              Iceberg Mobile Mega Data/Printer Cart  1564.29
# 9386                                          Xerox 191    79.92
# 9387                                         Xerox 1881    12.28
# 9388                    Avanti 4.4 Cu. Ft. Refrigerator   542.94
# 9389                          Poly String Tie Envelopes     2.04
# 9741  Riverside Palais Royal Lawyers Bookcase, Royal...  4404.90
#
#       Shipping_timeframe
# 2234                 153
# 5274                  62
# 8798                 122
# 9146                   4
# 9147                   4
# 9148                   4
# 9386                   4
# 9387                   4
# 9388                   4
# 9389                   4
# 9741                 122

# %%
data['Postal Code'] = data['Postal Code'].fillna('05402')
data[(data.City == 'Burlington') & (data.State == 'Vermont')]
#I filled with null values of Postal Code with generally a most used one.
# Out:
#             Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 2234  CA-2018-104066 2018-05-12 2018-10-12  Standard Class    QJ-19255
# 5274  CA-2016-162887 2016-07-11 2016-09-11    Second Class    SV-20785
# 8798  US-2017-150140 2017-06-04 2017-10-04  Standard Class    VM-21685
# 9146  US-2017-165505 2017-01-23 2017-01-27  Standard Class    CB-12535
# 9147  US-2017-165505 2017-01-23 2017-01-27  Standard Class    CB-12535
# 9148  US-2017-165505 2017-01-23 2017-01-27  Standard Class    CB-12535
# 9386  US-2018-127292 2018-01-19 2018-01-23  Standard Class    RM-19375
# 9387  US-2018-127292 2018-01-19 2018-01-23  Standard Class    RM-19375
# 9388  US-2018-127292 2018-01-19 2018-01-23  Standard Class    RM-19375
# 9389  US-2018-127292 2018-01-19 2018-01-23  Standard Class    RM-19375
# 9741  CA-2016-117086 2016-08-11 2016-12-11  Standard Class    QJ-19255
#
#          Customer Name      Segment        City    State Postal Code Region  \
# 2234      Quincy Jones    Corporate  Burlington  Vermont       05402   East
# 5274  Stewart Visinsky     Consumer  Burlington  Vermont       05402   East
# 8798   Valerie Mitchum  Home Office  Burlington  Vermont       05402   East
# 9146  Claudia Bergmann    Corporate  Burlington  Vermont       05402   East
# 9147  Claudia Bergmann    Corporate  Burlington  Vermont       05402   East
# 9148  Claudia Bergmann    Corporate  Burlington  Vermont       05402   East
# 9386     Raymond Messe     Consumer  Burlington  Vermont       05402   East
# 9387     Raymond Messe     Consumer  Burlington  Vermont       05402   East
# 9388     Raymond Messe     Consumer  Burlington  Vermont       05402   East
# 9389     Raymond Messe     Consumer  Burlington  Vermont       05402   East
# 9741      Quincy Jones    Corporate  Burlington  Vermont       05402   East
#
#            Product ID         Category Sub-Category  \
# 2234  TEC-AC-10001013       Technology  Accessories
# 5274  FUR-CH-10000595        Furniture       Chairs
# 8798  TEC-PH-10002555       Technology       Phones
# 9146  TEC-AC-10002926       Technology  Accessories
# 9147  OFF-AR-10003477  Office Supplies          Art
# 9148  OFF-ST-10001526  Office Supplies      Storage
# 9386  OFF-PA-10000157  Office Supplies        Paper
# 9387  OFF-PA-10001970  Office Supplies        Paper
# 9388  OFF-AP-10000828  Office Supplies   Appliances
# 9389  OFF-EN-10001509  Office Supplies    Envelopes
# 9741  FUR-BO-10004834        Furniture    Bookcases
#
#                                            Product Name    Sales  \
# 2234        Logitech ClearChat Comfort/USB Headset H390   205.03
# 5274                    Safco Contoured Stacking Chairs   715.20
# 8798                Nortel Meridian M5316 Digital phone  1294.75
# 9146              Logitech Wireless Marathon Mouse M705    99.98
# 9147                                  4009 Highlighters     8.04
# 9148              Iceberg Mobile Mega Data/Printer Cart  1564.29
# 9386                                          Xerox 191    79.92
# 9387                                         Xerox 1881    12.28
# 9388                    Avanti 4.4 Cu. Ft. Refrigerator   542.94
# 9389                          Poly String Tie Envelopes     2.04
# 9741  Riverside Palais Royal Lawyers Bookcase, Royal...  4404.90
#
#       Shipping_timeframe
# 2234                 153
# 5274                  62
# 8798                 122
# 9146                   4
# 9147                   4
# 9148                   4
# 9386                   4
# 9387                   4
# 9388                   4
# 9389                   4
# 9741                 122

# %% [markdown]
# # Data visualization and story telling
#
# In this part of this analysis, I will visualize the data to answer the questions and to understand more clearly our data that mentioned at the beginning.

# %% [markdown]
# # Daily sales

# %%
data_daily_sales = data.groupby('Order Date').agg({'Sales':"sum"}).reset_index()
#I grouped  my dataset by "Order Date" and I want that according to "Sales" sum.
data_daily_sales
# Out:
#      Order Date      Sales
# 0    2015-01-02   468.9000
# 1    2015-01-03  2203.1510
# 2    2015-01-04   119.8880
# 3    2015-01-06  5188.5200
# 4    2015-01-07   601.0240
# ...         ...        ...
# 1225 2018-12-26   814.5940
# 1226 2018-12-27   177.6360
# 1227 2018-12-28  1657.3508
# 1228 2018-12-29  2915.5340
# 1229 2018-12-30   713.7900
#
# [1230 rows x 2 columns]

# %%
data.groupby(['Order Date', 'Ship Mode']).agg({'Sales':'sum'})
#I just want to see the "Ship Mode" and "Order Date" together.
# Out:
#                                Sales
# Order Date Ship Mode
# 2015-01-02 First Class      468.9000
# 2015-01-03 Second Class     457.5680
#            Standard Class  1745.5830
# 2015-01-04 Second Class      46.6880
#            Standard Class    73.2000
# ...                              ...
# 2018-12-28 Standard Class   589.6188
# 2018-12-29 First Class        6.0300
#            Second Class    1814.6800
#            Standard Class  1094.8240
# 2018-12-30 Standard Class   713.7900
#
# [2475 rows x 1 columns]

# %%
# fig = px.line(data_daily_sales, x='Order Date', y='Sales', title='Daily Sales')
# fig
sns.lineplot(x='Order Date', y='Sales',data=data_daily_sales).set(title="Daily Sales")
plt.xticks(rotation=45);
#Generally, using line graph is more logical for daily information.
# I can say that seasonality(christmas- black friday extc) is not included in this data as it is a store that are selling office supplies.

# %% [markdown]
# # Monthly sales over the years

# %%
data.dtypes
#Since the type of order date column is datetime, I can use pandas dt method.
# Out:
# Order ID                      object
# Order Date            datetime64[ns]
# Ship Date             datetime64[ns]
# Ship Mode                     object
# Customer ID                   object
# Customer Name                 object
# Segment                       object
# City                          object
# State                         object
# Postal Code                   object
# Region                        object
# Product ID                    object
# Category                      object
# Sub-Category                  object
# Product Name                  object
# Sales                        float64
# Shipping_timeframe             int32
# dtype: object

# %%
data['year'] = data['Order Date'].dt.year
data['month'] = data['Order Date'].dt.month
data['month_year'] = str(data.month) + '-' + str(data.year)

# %%
for i in range(len(data)):
  data['month_year'][i] = str(data.month[i]) + "-" +str(data.year[i])

#If I want to combine two data, it is usually added as a string data type, and I add it this way.
data['month_year'] = pd.to_datetime(data['month_year'])

# %%
data.head()
# Out:
#          Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0  CA-2017-152156 2017-08-11 2017-11-11    Second Class    CG-12520
# 1  CA-2017-152156 2017-08-11 2017-11-11    Second Class    CG-12520
# 2  CA-2017-138688 2017-12-06 2017-12-10    Second Class    DV-13045
# 3  US-2016-108966 2016-11-10 2016-11-16  Standard Class    SO-20335
# 4  US-2016-108966 2016-11-10 2016-11-16  Standard Class    SO-20335
#
#      Customer Name    Segment             City       State Postal Code Region  \
# 0      Claire Gute   Consumer        Henderson    Kentucky     42420.0  South
# 1      Claire Gute   Consumer        Henderson    Kentucky     42420.0  South
# 2  Darrin Van Huff  Corporate      Los Angeles  California     90036.0   West
# 3   Sean O'Donnell   Consumer  Fort Lauderdale     Florida     33311.0  South
# 4   Sean O'Donnell   Consumer  Fort Lauderdale     Florida     33311.0  South
#
#         Product ID         Category Sub-Category  \
# 0  FUR-BO-10001798        Furniture    Bookcases
# 1  FUR-CH-10000454        Furniture       Chairs
# 2  OFF-LA-10000240  Office Supplies       Labels
# 3  FUR-TA-10000577        Furniture       Tables
# 4  OFF-ST-10000760  Office Supplies      Storage
#
#                                         Product Name     Sales  \
# 0                  Bush Somerset Collection Bookcase  261.9600
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775
# 4                     Eldon Fold 'N Roll Cart System   22.3680
#
#    Shipping_timeframe  year  month month_year
# 0                  92  2017      8 2017-08-01
# 1                  92  2017      8 2017-08-01
# 2                   4  2017     12 2017-12-01
# 3                   6  2016     11 2016-11-01
# 4                   6  2016     11 2016-11-01

# %%
data_month_year = data.groupby(['month_year']).agg({'Sales': 'sum'}).reset_index()

# %%
plt.title('Month and yearly sales')
sns.scatterplot(data=data_month_year,x='month_year', y='Sales')
plt.xticks(rotation=45);

# %% [markdown]
# # Monthly average sales

# %%
data_monthly_avg = data.groupby(['month']).agg({'Sales': 'mean'}).reset_index()
sns.barplot(x='month', y='Sales', data=data_monthly_avg).set(title="Monthly average sales");

# %% [markdown]
# # Average sales by day of the week

# %%
data.head()
# Out:
#          Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0  CA-2017-152156 2017-08-11 2017-11-11    Second Class    CG-12520
# 1  CA-2017-152156 2017-08-11 2017-11-11    Second Class    CG-12520
# 2  CA-2017-138688 2017-12-06 2017-12-10    Second Class    DV-13045
# 3  US-2016-108966 2016-11-10 2016-11-16  Standard Class    SO-20335
# 4  US-2016-108966 2016-11-10 2016-11-16  Standard Class    SO-20335
#
#      Customer Name    Segment             City       State Postal Code Region  \
# 0      Claire Gute   Consumer        Henderson    Kentucky     42420.0  South
# 1      Claire Gute   Consumer        Henderson    Kentucky     42420.0  South
# 2  Darrin Van Huff  Corporate      Los Angeles  California     90036.0   West
# 3   Sean O'Donnell   Consumer  Fort Lauderdale     Florida     33311.0  South
# 4   Sean O'Donnell   Consumer  Fort Lauderdale     Florida     33311.0  South
#
#         Product ID         Category Sub-Category  \
# 0  FUR-BO-10001798        Furniture    Bookcases
# 1  FUR-CH-10000454        Furniture       Chairs
# 2  OFF-LA-10000240  Office Supplies       Labels
# 3  FUR-TA-10000577        Furniture       Tables
# 4  OFF-ST-10000760  Office Supplies      Storage
#
#                                         Product Name     Sales  \
# 0                  Bush Somerset Collection Bookcase  261.9600
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775
# 4                     Eldon Fold 'N Roll Cart System   22.3680
#
#    Shipping_timeframe  year  month month_year
# 0                  92  2017      8 2017-08-01
# 1                  92  2017      8 2017-08-01
# 2                   4  2017     12 2017-12-01
# 3                   6  2016     11 2016-11-01
# 4                   6  2016     11 2016-11-01

# %%
data['weekday'] = data['Order Date'].dt.day_name()
#I look at the "Order date" column using pandas dt method to find out which day the sale was made.

# %%
colorscales = px.colors.named_colorscales()
data_weekday = data.groupby(['weekday']).agg({'Sales': 'mean'}).reset_index()
data_weekday.sort_values(by='Sales', inplace=True)
sns.barplot(x='weekday', y='Sales', data=data_weekday).set(title="Average sales by day of the week");

# %%
data['quarter'] = data['Order Date'].dt.quarter
#It is method that obtain quarter value of chosen column.

# %%
data.head()
# Out:
#          Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0  CA-2017-152156 2017-08-11 2017-11-11    Second Class    CG-12520
# 1  CA-2017-152156 2017-08-11 2017-11-11    Second Class    CG-12520
# 2  CA-2017-138688 2017-12-06 2017-12-10    Second Class    DV-13045
# 3  US-2016-108966 2016-11-10 2016-11-16  Standard Class    SO-20335
# 4  US-2016-108966 2016-11-10 2016-11-16  Standard Class    SO-20335
#
#      Customer Name    Segment             City       State Postal Code  ...  \
# 0      Claire Gute   Consumer        Henderson    Kentucky     42420.0  ...
# 1      Claire Gute   Consumer        Henderson    Kentucky     42420.0  ...
# 2  Darrin Van Huff  Corporate      Los Angeles  California     90036.0  ...
# 3   Sean O'Donnell   Consumer  Fort Lauderdale     Florida     33311.0  ...
# 4   Sean O'Donnell   Consumer  Fort Lauderdale     Florida     33311.0  ...
#
#           Category Sub-Category  \
# 0        Furniture    Bookcases
# 1        Furniture       Chairs
# 2  Office Supplies       Labels
# 3        Furniture       Tables
# 4  Office Supplies      Storage
#
#                                         Product Name     Sales  \
# 0                  Bush Somerset Collection Bookcase  261.9600
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775
# 4                     Eldon Fold 'N Roll Cart System   22.3680
#
#   Shipping_timeframe  year  month  month_year    weekday quarter
# 0                 92  2017      8  2017-08-01     Friday       3
# 1                 92  2017      8  2017-08-01     Friday       3
# 2                  4  2017     12  2017-12-01  Wednesday       4
# 3                  6  2016     11  2016-11-01   Thursday       4
# 4                  6  2016     11  2016-11-01   Thursday       4
#
# [5 rows x 22 columns]

# %%
data_quarter = data.groupby('quarter').agg({'Sales': 'mean'}).reset_index()
ax= sns.barplot(x='quarter', y='Sales', data=data_quarter, color="olivedrab");
ax.bar_label(ax.containers[0]);
# Out:
# <bound method Axes.bar_label of <AxesSubplot:xlabel='quarter', ylabel='Sales'>>

# %% [markdown]
# # Year over growth year/ Total sales over the years

# %%
data_year=data.groupby('year').agg({'Sales': 'sum'}).reset_index()
ax= sns.barplot(x='year', y='Sales', data=data_year, color="crimson").set(title="Total sales over the years");

# %%
data_year['yoy'] = round(data_year['Sales'].pct_change()*100, 2)
sns.barplot(x='year', y='yoy', data=data_year).set(title="Year over growth year");
#It is the method to get the percentage change of chosen column.
#"yoy"= year over growth year

# %% [markdown]
# # Top customer of all times

# %%
data_top_customer = data.groupby('Customer Name').agg({'Sales': 'sum'}).reset_index()
data_top_customer.sort_values(by='Sales',ascending=False, inplace=True)
sns.barplot(x='Customer Name', y='Sales', data=data_top_customer.head(10), color="purple");
plt.xticks(rotation=45);

# %% [markdown]
# # Top customers by years

# %%
data_top_cust_year = data.groupby(['Customer Name', 'year']).agg({'Sales':'sum'}).reset_index()

#px.bar(data_top_cust_year[data_top_cust_year['year']== 2015], x='Customer Name', y='Sales',title='top customer 2015')
#Here, I filtered only the information of all sales in 2015.

data_top_cust_2015 = data_top_cust_year[data_top_cust_year['year']== 2015].sort_values(by='Sales', ascending=False)
sns.barplot(x='Customer Name', y='Sales', data=data_top_cust_2015.head(10), color="lightseagreen");
plt.xticks(rotation=45);

# %% [markdown]
# # Top cities

# %%
data_city = data.groupby(['City']).agg({'Sales': 'sum'}).reset_index()
data_city.sort_values(by='Sales', ascending=False, inplace=True)

sns.barplot(x='City', y='Sales', data=data_city.head(10), color="coral").set(title="Top 10 city");
plt.xticks(rotation=45);

# %% [markdown]
# # Regional Sales

# %%
data_region= data.groupby('Region').agg(sales_sum=('Sales','sum'), sales_mean=('Sales', 'mean')).reset_index()
#Since I want to look at the average and the sum of our sales column at the same time, I used tuples like this.

# %%
data_region
# Out:
#     Region    sales_sum  sales_mean
# 0  Central  492646.9132  216.357889
# 1     East  669518.7260  240.401697
# 2    South  389151.4590  243.524067
# 3     West  710219.6845  226.184613

# %%
data_region.sort_values(by='sales_sum', ascending=False, inplace=True)
sns.barplot(x='Region', y='sales_sum', data=data_region,palette ="hls").set(title="Regional sum");

# %% [markdown]
# # Sales by category, subcategory and product

# %%
data_cat = data.groupby(['Category']).agg({'Sales':'sum'}).reset_index().sort_values(by='Sales', ascending=False)
sns.barplot(x='Category', y='Sales', data=data_cat).set(title="Sales by Category'");

# %% [markdown]
# # Sub category

# %%
data_sub_cat = data.groupby(['Sub-Category']).agg({'Sales':'sum'}).reset_index().sort_values(by='Sales', ascending=False)
sns.barplot(x='Sub-Category', y='Sales', data=data_sub_cat, color="yellowgreen")
plt.xticks(rotation=45);

# %% [markdown]
#  # Sales by product

# %%
data_product = data.groupby(['Product Name']).agg({'Sales':'sum'}).reset_index()
sns.barplot(x='Product Name', y='Sales', data=data_product.head(5), color="aquamarine")
plt.xticks(rotation=45);

# %% [markdown]
# # Top products in each subcategory

# %%
data_top_prod = data.groupby(['Sub-Category', 'Product Name']).agg({'Sales':'sum'}).reset_index()
data_top_prod.sort_values(by=['Sales'], ascending=False, inplace=True)

# %%
data_top_prod.head()
# Out:
#      Sub-Category                                       Product Name  \
# 757       Copiers              Canon imageCLASS 2200 Advanced Copier
# 483       Binders  Fellowes PB500 Electric Punch Plastic Comb Bin...
# 1111     Machines  Cisco TelePresence System EX90 Videoconferenci...
# 702        Chairs       HON 5400 Series Task Chairs for Big and Tall
# 495       Binders         GBC DocuBind TL300 Electric Binding System
#
#           Sales
# 757   61599.824
# 483   27453.384
# 1111  22638.480
# 702   21870.576
# 495   19823.479

# %%
data_top_prod['rank'] =data_top_prod.groupby(['Sub-Category'])['Sales'].rank('dense',ascending=False)
#It is a method to get each sub-category number one product.

# %%
data_top_prod[data_top_prod['Sub-Category'] =='Machines']
# Out:
#      Sub-Category                                       Product Name  \
# 1111     Machines  Cisco TelePresence System EX90 Videoconferenci...
# 1119     Machines  HP Designjet T520 Inkjet Large Format Printer ...
# 1131     Machines          Lexmark MX611dhe Monochrome Laser Printer
# 1097     Machines   3D Systems Cube Printer, 2nd Generation, Magenta
# 1112     Machines          Cubify CubeX 3D Printer Double Head Print
# ...           ...                                                ...
# 1126     Machines  Hewlett-Packard Deskjet F4180 All-in-One Color...
# 1144     Machines                Penpower WorldCard Pro Card Scanner
# 1154     Machines       Vtech AT&T CL2940 Corded Speakerphone, Black
# 1152     Machines         Texas Instrument TI-15 Fraction Calculator
# 1145     Machines                     Plantronics Single Ear Headset
#
#           Sales  rank
# 1111  22638.480   1.0
# 1119  18374.895   2.0
# 1131  16829.901   3.0
# 1097  14299.890   4.0
# 1112  11099.963   5.0
# ...         ...   ...
# 1126    101.994  59.0
# 1144     91.475  60.0
# 1154     71.976  61.0
# 1152     41.905  62.0
# 1145     29.925  63.0
#
# [63 rows x 4 columns]

# %%
data_top_prod[data_top_prod['Sub-Category'] =='Accessories']
# Out:
#     Sub-Category                                       Product Name  \
# 114  Accessories  Plantronics CS510 - Over-the-Head monaural Wir...
# 71   Accessories                 Logitech P710e Mobile Speakerphone
# 116  Accessories  Plantronics Savi W720 Multi-Device Wireless He...
# 66   Accessories                      Logitech diNovo Edge Keyboard
# 74   Accessories  Logitech Z-906 Speaker sys - home theater - 5....
# ..           ...                                                ...
# 124  Accessories                SanDisk Cruzer 4 GB USB Flash Drive
# 78   Accessories                          Maxell 4.7GB DVD-R 5/Pack
# 82   Accessories                                  Maxell CD-R Discs
# 97   Accessories  Memorex Mini Travel Drive 4 GB USB 2.0 Flash D...
# 75   Accessories                          Maxell 4.7GB DVD+R 5/Pack
#
#          Sales   rank
# 114  10822.360    1.0
# 71   10196.604    2.0
# 116   9367.290    3.0
# 66    7399.704    4.0
# 74    5609.830    5.0
# ..         ...    ...
# 124     25.960  143.0
# 78      19.008  144.0
# 82      15.760  145.0
# 97      13.616  146.0
# 75      11.682  147.0
#
# [147 rows x 4 columns]

# %%
px.bar(data_top_prod[data_top_prod['rank'] == 1], x='Product Name', y='Sales', color='Sub-Category', title='Top products in each sub category',width=1000, height=800, text_auto=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.18.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="bb9dd6d1-afa7-48cc-9235-a20a2393f81f" class="plotly-graph-div" style="height:800px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bb9dd6d1-afa7-48cc-9235-a20a2393f81f")) {                    Plotly.newPlot(                        "bb9dd6d1-afa7-48cc-9235-a20a2393f81f",                        [{"alignmentgroup":"True","hovertemplate":"Sub-Category=Copiers<br>Product Name=%{x}<br>Sales=%{y}<extra></extra>","legendgroup":"Copiers","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Copiers","offsetgroup":"Copiers","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Canon imageCLASS 2200 Advanced Copier"],"xaxis":"x","y":[61599.824],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sub-Category=Binders<br>Product Name=%{x}<br>Sales=%{y}<extra></extra>","legendgroup":"Binders","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Binders","offsetgroup":"Binders","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Fellowes PB500 Electric Punch Plastic Comb Binding Machine with Manual Bind"],"xaxis":"x","y":[27453.384000000002],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sub-Category=Machines<br>Product Name=%{x}<br>Sales=%{y}<extra></extra>","legendgroup":"Machines","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Machines","offsetgroup":"Machines","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Cisco TelePresence System EX90 Videoconferencing Unit"],"xaxis":"x","y":[22638.48],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sub-Category=Chairs<br>Product Name=%{x}<br>Sales=%{y}<extra></extra>","legendgroup":"Chairs","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Chairs","offsetgroup":"Chairs","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["HON 5400 Series Task Chairs for Big and Tall"],"xaxis":"x","y":[21870.576],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sub-Category=Supplies<br>Product Name=%{x}<br>Sales=%{y}<extra></extra>","legendgroup":"Supplies","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Supplies","offsetgroup":"Supplies","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["High Speed Automatic Electric Letter Opener"],"xaxis":"x","y":[17030.311999999998],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sub-Category=Bookcases<br>Product Name=%{x}<br>Sales=%{y}<extra></extra>","legendgroup":"Bookcases","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Bookcases","offsetgroup":"Bookcases","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Riverside Palais Royal Lawyers Bookcase, Royale Cherry Finish"],"xaxis":"x","y":[15610.9656],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sub-Category=Phones<br>Product Name=%{x}<br>Sales=%{y}<extra></extra>","legendgroup":"Phones","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Phones","offsetgroup":"Phones","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Samsung Galaxy Mega 6.3"],"xaxis":"x","y":[13943.668],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sub-Category=Tables<br>Product Name=%{x}<br>Sales=%{y}<extra></extra>","legendgroup":"Tables","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Tables","offsetgroup":"Tables","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Bretford Rectangular Conference Table Tops"],"xaxis":"x","y":[12995.2915],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sub-Category=Accessories<br>Prod ...

# %% [markdown]
# # Conclusion <a id="paragraph4"></a>
# According to data visualization;
#
# * Saturday and Thursday of the week are sales high on average.
# * Monthly average sales is highest at January.
# * Total sales is highest at 2018 but for year over growth year is at highest at 2017.
# * Top customer for all times is Sean Miller who is in segment of Home Office.
# * The highest sales by category is Technology.
# * New York has the highest sales then Los Angeles came. These are big and crowded city, for example it may be desirable to open another store in these city.
